# %%
print("hello world")

# %%
import matplotlib.pyplot as plt

x = [34,23,54,65,23]
y = [2002,2003,2004,2005,2006]

plt.bar(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 x = [34,23,54,65,23]
#       2 y = [2002,2003,2004,2005,2006]
#       3
# ----> 4 plt.bar(x,y)
#       5 plt.show()
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2375, in bar(x, height, width, bottom, align, data, **kwargs)
#    2371 @_copy_docstring_and_deprecators(Axes.bar)
#    2372 def bar(
#    2373         x, height, width=0.8, bottom=None, *, align='center',
#    2374         data=None, **kwargs):
# -> 2375     return gca().bar(
#    2376         x, height, width=width, bottom=bottom, align=align,
#    2377         **({"data": data} if data is not None else {}), **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2245, in gca()
#    2243 @_copy_docstring_and_deprecators(Figure.gca)
#    2244 def gca():
# -> 2245     return gcf().gca()
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Out:
#   Cell In[11], line 1
#     pip3 install matplotlib --break-system-packages
#          ^
# SyntaxError: invalid syntax
